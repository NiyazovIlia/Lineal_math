# %% [markdown]
# <a href="https://colab.research.google.com/github/NiyazovIlia/Lineal_math/blob/lesson-1/%D0%9B%D0%B8%D0%BD%D0%B5%D0%B9%D0%BD%D0%B0%D1%8F_%D0%B0%D0%BB%D0%B3%D0%B5%D0%B1%D1%80%D0%B0_%D1%83%D1%80%D0%BE%D0%BA_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1 Часть**

# %% [markdown]
# ![xXDWz-kNaXM.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **2 Часть**

# %% [markdown]
# 1. Найти скалярное произведение векторов  x,y∈R :
#
# а)  x=(0,−3,6), y=(−4,7,9);
#
# б)  x=(7,−4,0,1), y=(−3,1,11,2).

# %%
import numpy as np
a = np.array([0,-3,6])
b = np.array([-4,7,9])
print(f'Скалярное произведение a и b:\n{np.dot(a, b)}')

c = np.array([7,-4,0,1])
d = np.array([-3,1,11,2])
print(f'Скалярное произведение c и d:\n{np.dot(c, d)}')
# Out:
# Скалярное произведение a и b:
# 33
# Скалярное произведение c и d:
# -23

# %% [markdown]
# Найти нормы векторов  (4,2,4)  и  (12,3,4)  и угол между ними.

# %%
from numpy.linalg import norm
a = np.array([4,2,4])
b = np.array([12,3,4])

print(f'l1 Манхетовская норма вектора a:\n{norm(a, ord=1)}')
print(f'l1 Манхетовская норма вектора b:\n{norm(b, ord=1)}')

print(f'l2 Евклидова норма вектора а:\n{norm(a, ord=2)}')
print(f'l2 Евклидова норма вектора b:\n{norm(b, ord=2)}')

cos_phi = np.dot(a, b) / norm(a) / norm(b)
print(f'Угол между векторами a и b: {cos_phi}')
# Out:
# l1 Манхетовская норма вектора a:
# 10.0
# l1 Манхетовская норма вектора b:
# 19.0
# l2 Евклидова норма вектора а:
# 6.0
# l2 Евклидова норма вектора b:
# 13.0
# Угол между векторами a и b: 0.8974358974358974

# %% [markdown]
# Будет ли линейное пространство евклидовым, если за скалярное произведение принять:
#
# а) произведение длин векторов;
#
# б) утроенное обычное скалярное произведение векторов?
#
# **Ответ:**
#
# Да, оба эти утверждения можно принять за евклидово, так как длина вектора это его коррдинаты, если известны его координаты то можно найти скалярное произведение, что утверждается определением.

# %% [markdown]
# Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве  R3 :
#
# а)  (1,0,0),(0,0,1);
#
# б)  (1/2–√,−1/2–√,0),(1/2–√,1/2–√,0),(0,0,1);
#
# в)  (1/2,−1/2,0),(0,1/2,1/2),(0,0,1);
#
# г)  (1,0,0),(0,1,0),(0,0,1)?
#
# **Ответ:**
#
# Б и Г будут представлять ортонормированный базис, так как они попарно ортогональны, а длины векторов равны 1
